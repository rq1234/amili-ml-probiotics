# %% [markdown]
# # Process Data for Machine Learning

# %%
import os
import pandas as pd
import numpy as np
import sys
import zipfile
from dotenv import load_dotenv
from IPython.display import Markdown
import matplotlib.pyplot as plt
import seaborn as sns
load_dotenv()
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, make_scorer, f1_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report, confusion_matrix

# %%
ZIP_FILE = "datasets/hospital_readmission/diabetic_data_initial.csv.zip"

import zipfile
import pandas as pd

with zipfile.ZipFile(ZIP_FILE, 'r') as z:
    print(z.namelist())  # Optional: check file inside ZIP
    with z.open(z.namelist()[0]) as f:
        df = pd.read_csv(f)

df.head()
# Out:
# ['diabetic_data_initial.csv', '__MACOSX/._diabetic_data_initial.csv']
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                 1  ...          No      No                   No
# 1                 3  ...          No      Up                   No
# 2                 2  ...          No      No                   No
# 3                 2  ...          No      Up                   No
# 4                 1  ...          No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
#
# [5 rows x 50 columns]

# %%
#checking shape of the dataset
df.shape

#Checking data types of each variable
df.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# chlorpropamide              object
# glimepiride                 object
# acetohexamide               object
# glipizide                   object
# glyburide                   object
# tolbutamide                 object
# pioglitazone                object
# rosiglitazone               object
# acarbose                    object
# miglitol                    object
# troglitazone                object
# tolazamide                  object
# examide                     object
# citoglipton                 object
# insulin                     object
# glyburide-metformin         object
# glipizide-metformin         object
# glimepiride-pioglitazone    object
# metformin-rosiglitazone     object
# metformin-pioglitazone      object
# change                      object
# diabetesMed                 object
# readmitted                  object
# dtype: object

# %%
#Checking for missing values in dataset
#In the dataset missing values are represented as '?' sign
for col in df.columns:
    if df[col].dtype == object:
         print(col,df[col][df[col] == '?'].count())
# Out:
# race 2273
# gender 0
# age 0
# weight 98569
# payer_code 40256
# medical_specialty 49949
# diag_1 21
# diag_2 358
# diag_3 1423
# max_glu_serum 0
# A1Cresult 0
# metformin 0
# repaglinide 0
# nateglinide 0
# chlorpropamide 0
# glimepiride 0
# acetohexamide 0
# glipizide 0
# glyburide 0
# tolbutamide 0
# pioglitazone 0
# rosiglitazone 0
# acarbose 0
# miglitol 0
# troglitazone 0
# tolazamide 0
# examide 0
# citoglipton 0
# insulin 0
# glyburide-metformin 0
# glipizide-metformin 0
# glimepiride-pioglitazone 0
# metformin-rosiglitazone 0
# metformin-pioglitazone 0
# change 0
# diabetesMed 0
# readmitted 0

# %%
# gender was coded differently so we use a custom count for this one            
print('gender', df['gender'][df['gender'] == 'Unknown/Invalid'].count())
# Out:
# gender 3

# %%
#dropping columns with large number of missing values
df = df.drop(['weight','payer_code','medical_specialty'], axis = 1)

# %%
drop_Idx = set(df[(df['diag_1'] == '?') & (df['diag_2'] == '?') & (df['diag_3'] == '?')].index)

drop_Idx = drop_Idx.union(set(df['diag_1'][df['diag_1'] == '?'].index))
drop_Idx = drop_Idx.union(set(df['diag_2'][df['diag_2'] == '?'].index))
drop_Idx = drop_Idx.union(set(df['diag_3'][df['diag_3'] == '?'].index))
drop_Idx = drop_Idx.union(set(df['race'][df['race'] == '?'].index))
drop_Idx = drop_Idx.union(set(df[df['discharge_disposition_id'] == 11].index))
drop_Idx = drop_Idx.union(set(df['gender'][df['gender'] == 'Unknown/Invalid'].index))
new_Idx = list(set(df.index) - set(drop_Idx))
df = df.iloc[new_Idx]

# %%
#Checking for missing values in the data
for col in df.columns:
    if df[col].dtype == object:
         print(col,df[col][df[col] == '?'].count())
            
print('gender', df['gender'][df['gender'] == 'Unknown/Invalid'].count())
# Out:
# race 0
# gender 0
# age 0
# diag_1 0
# diag_2 0
# diag_3 0
# max_glu_serum 0
# A1Cresult 0
# metformin 0
# repaglinide 0
# nateglinide 0
# chlorpropamide 0
# glimepiride 0
# acetohexamide 0
# glipizide 0
# glyburide 0
# tolbutamide 0
# pioglitazone 0
# rosiglitazone 0
# acarbose 0
# miglitol 0
# troglitazone 0
# tolazamide 0
# examide 0
# citoglipton 0
# insulin 0
# glyburide-metformin 0
# glipizide-metformin 0
# glimepiride-pioglitazone 0
# metformin-rosiglitazone 0
# metformin-pioglitazone 0
# change 0
# diabetesMed 0
# readmitted 0
# gender 0

# %%
readmit_map = {'<30': 0, '>30': 1, 'NO': 2}
df['readmitted'] = df['readmitted'].map(readmit_map)

# %%
# Drop rows where mapping failed (if any)
df = df[df['readmitted'].notna()]
df['readmitted'] = df['readmitted'].astype(int)

# %%
# Step 3: Select Features
# -----------------------------
selected_cols = [
    'race', 'gender', 'age', 'admission_type_id', 'discharge_disposition_id',
    'admission_source_id', 'time_in_hospital', 'num_lab_procedures',
    'num_procedures', 'num_medications', 'number_outpatient', 'number_emergency',
    'number_inpatient', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
    'metformin', 'insulin', 'change', 'diabetesMed'
]

X = df[selected_cols]
y = df['readmitted']

# %%
X = df[selected_cols]
y = df['readmitted']

# -----------------------------
# Step 4: Encode Categorical Features
# -----------------------------
X = X.copy()
for col in X.select_dtypes(include='object').columns:
    X[col] = LabelEncoder().fit_transform(X[col])

# %%
print("Class distribution:\n", y.value_counts())
# Out:
# Class distribution:
#  readmitted
# 2    50731
# 1    34649
# 0    11066
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=42)

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
print("Resampled training set class distribution:")
print(pd.Series(y_train_resampled).value_counts())
# Out:
# Resampled training set class distribution:
# readmitted
# 1    35512
# 2    35512
# 0    35512
# Name: count, dtype: int64

# %%
from sklearn.utils.class_weight import compute_sample_weight
sample_weights = compute_sample_weight(class_weight='balanced', y=y_train_resampled)

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7, 10],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'gamma': [0, 0.1, 0.2],
    'min_child_weight': [1, 5, 10]
}

xgb = XGBClassifier(
    objective='multi:softprob',
    num_class=3,
    use_label_encoder=False,
    eval_metric='mlogloss',
    random_state=42
)

f1_macro = make_scorer(f1_score, average='macro')

clf = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=param_grid,
    scoring=f1_macro,
    n_iter=25,
    cv=3,
    verbose=1,
    n_jobs=-1
)

clf.fit(X_train_resampled, y_train_resampled, sample_weight=sample_weights)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# c:\Users\rongq\OneDrive\0 Rong\01 Documents\AMILI\amili-ai-mcp\.venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [16:12:38] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric='mlogloss',
#                                            feature_types=None,
#                                            feature_weights=None, gamma=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_con...
#                                            n_estimators=None, n_jobs=None,
#                                            num_class=3, ...),
#                    n_iter=25, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.6, 0.8, 1.0],
#                                         'gamma': [0, 0.1, 0.2],
#                                         'learning_rate': [0.01, 0.1, 0.2],
#                                         'max_depth': [3, 5, 7, 10],
#                                         'min_child_weight': [1, 5, 10],
#                                         'n_estimators': [100, 200, 300],
#                                         'subsample': [0.8, 1.0]},
#                    scoring=make_scorer(f1_score, response_method='predict', average=macro),
#                    verbose=1)

# %%
best_params = clf.best_params_

final_model = XGBClassifier(
    objective='multi:softprob',
    num_class=3,
    eval_metric='mlogloss',
    use_label_encoder=False,
    **best_params
)

final_model.fit(
    X_train_resampled,
    y_train_resampled,
    sample_weight=sample_weights,
    eval_set=[(X_test, y_test)],
    verbose=True
)

# Step 6: Threshold tuning for class <30>
probs = final_model.predict_proba(X_test)

# Custom threshold for class 0 ("<30")
threshold = 0.3
y_pred_custom = np.where(probs[:, 0] > threshold, 0, np.argmax(probs, axis=1))

# Step 7: Evaluation
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_custom))
print("Classification Report:\n", classification_report(y_test, y_pred_custom, target_names=['<30', '>30', 'NO']))
# Out:
# [0]	validation_0-mlogloss:1.08902
# [1]	validation_0-mlogloss:1.07979
# [2]	validation_0-mlogloss:1.07096
# [3]	validation_0-mlogloss:1.06524
# c:\Users\rongq\OneDrive\0 Rong\01 Documents\AMILI\amili-ai-mcp\.venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [16:13:13] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [4]	validation_0-mlogloss:1.05910
# [5]	validation_0-mlogloss:1.05266
# [6]	validation_0-mlogloss:1.04723
# [7]	validation_0-mlogloss:1.04211
# [8]	validation_0-mlogloss:1.03796
# [9]	validation_0-mlogloss:1.03353
# [10]	validation_0-mlogloss:1.02888
# [11]	validation_0-mlogloss:1.02563
# [12]	validation_0-mlogloss:1.02206
# [13]	validation_0-mlogloss:1.01968
# [14]	validation_0-mlogloss:1.01639
# [15]	validation_0-mlogloss:1.01352
# [16]	validation_0-mlogloss:1.01085
# [17]	validation_0-mlogloss:1.00850
# [18]	validation_0-mlogloss:1.00637
# [19]	validation_0-mlogloss:1.00445
# [20]	validation_0-mlogloss:1.00292
# [21]	validation_0-mlogloss:1.00138
# [22]	validation_0-mlogloss:1.00022
# [23]	validation_0-mlogloss:0.99868
# [24]	validation_0-mlogloss:0.99733
# [25]	validation_0-mlogloss:0.99602
# [26]	validation_0-mlogloss:0.99480
# [27]	validation_0-mlogloss:0.99368
# [28]	validation_0-mlogloss:0.99270
# [29]	validation_0-mlogloss:0.99139
# [30]	validation_0-mlogloss:0.99045
# [31]	validation_0-mlogloss:0.98972
# [32]	validation_0-mlogloss:0.98890
# [33]	validation_0-mlogloss:0.98824
# [34]	validation_0-mlogloss:0.98789
# [35]	validation_0-mlogloss:0.98706
# [36]	validation_0-mlogloss:0.98641
# [37]	validation_0-mlogloss:0.98584
# [38]	validation_0-mlogloss:0.98538
# [39]	validation_0-mlogloss:0.98481
# [40]	validation_0-mlogloss:0.98453
# [41]	validation_0-mlogloss:0.98424
# [42]	validation_0-mlogloss:0.98387
# [43]	validation_0-mlogloss:0.98336
# [44]	validation_0-mlogloss:0.98305
# [45]	validation_0-mlogloss:0.98251
# [46]	validation_0-mlogloss:0.98229
# [47]	validation_0-mlogloss:0.98203
# [48]	validation_0-mlogloss:0.98158
# [49]	validation_0-mlogloss:0.98135
# [50]	validation_0-mlogloss:0.98109
# [51]	validation_0-mlogloss:0.98080
# [52]	validation_0-mlogloss:0.98051
# [53]	validation_0-mlogloss:0.98027
# [54]	validation_0-mlogloss:0.98015
# [55]	validation_0-mlogloss:0.97988
# [56]	validation_0-mlogloss:0.97963
# [57]	validation_0-mlogloss:0.97971
# [58]	validation_0-mlogloss:0.97940
# [59]	validation_0-mlogloss:0.97927
# [60]	validation_0-mlogloss:0.97917
# [61]	validation_0-mlogloss:0.97900
# [62]	validation_0-mlogloss:0.97884
# [63]	validation_0-mlogloss:0.97878
# [64]	validation_0-mlogloss:0.97868
# [65]	validation_0-mlogloss:0.97851
# [66]	validation_0-mlogloss:0.97842
# [67]	validation_0-mlogloss:0.97836
# [68]	validation_0-mlogloss:0.97830
# [69]	validation_0-mlogloss:0.97809
# [70]	validation_0-mlogloss:0.97790
# [71]	validation_0-mlogloss:0.97783
# [72]	validation_0-mlogloss:0.97781
# [73]	validation_0-mlogloss:0.97772
# [74]	validation_0-mlogloss:0.97764
# [75]	validation_0-mlogloss:0.97765
# [76]	validation_0-mlogloss:0.97758
# [77]	validation_0-mlogloss:0.97749
# [78]	validation_0-mlogloss:0.97732
# [79]	validation_0-mlogloss:0.97724
# [80]	validation_0-mlogloss:0.97726
# [81]	validation_0-mlogloss:0.97714
# [82]	validation_0-mlogloss:0.97699
# [83]	validation_0-mlogloss:0.97689
# [84]	validation_0-mlogloss:0.97695
# [85]	validation_0-mlogloss:0.97685
# [86]	validation_0-mlogloss:0.97675
# [87]	validation_0-mlogloss:0.97661
# [88]	validation_0-mlogloss:0.97650
# [89]	validation_0-mlogloss:0.97635
# [90]	validation_0-mlogloss:0.97638
# [91]	validation_0-mlogloss:0.97632
# [92]	validation_0-mlogloss:0.97619
# [93]	validation_0-mlogloss:0.97616
# [94]	validation_0-mlogloss:0.97603
# [95]	validation_0-mlogloss:0.97604
# [96]	validation_0-mlogloss:0.97592
# [97]	validation_0-mlogloss:0.97586
# [98]	validation_0-mlogloss:0.97586
# [99]	validation_0-mlogloss:0.97582
# [100]	validation_0-mlogloss:0.97592
# [101]	validation_0-mlogloss:0.97594
# [102]	validation_0-mlogloss:0.97588
# [103]	validation_0-mlogloss:0.97577
# [104]	validation_0-mlogloss:0.97590
# [105]	validation_0-mlogloss:0.97594
# [106]	validation_0-mlogloss:0.97599
# [107]	validation_0-mlogloss:0.97597
# [108]	validation_0-mlogloss:0.97593
# [109]	validation_0-mlogloss:0.97595
# [110]	validation_0-mlogloss:0.97594
# [111]	validation_0-mlogloss:0.97587
# [112]	validation_0-mlogloss:0.97581
# [113]	validation_0-mlogloss:0.97584
# [114]	validation_0-mlogloss:0.97579
# [115]	validation_0-mlogloss:0.97577
# [116]	validation_0-mlogloss:0.97579
# [117]	validation_0-mlogloss:0.97575
# [118]	validation_0-mlogloss:0.97570
# [119]	validation_0-mlogloss:0.97576
# [120]	validation_0-mlogloss:0.97587
# [121]	validation_0-mlogloss:0.97585
# [122]	validation_0-mlogloss:0.97597
# [123]	validation_0-mlogloss:0.97602
# [124]	validation_0-mlogloss:0.97596
# [125]	validation_0-mlogloss:0.97598
# [126]	validation_0-mlogloss:0.97603
# [127]	validation_0-mlogloss:0.97594
# [128]	validation_0-mlogloss:0.97591
# [129]	validation_0-mlogloss:0.97588
# [130]	validation_0-mlogloss:0.97597
# [131]	validation_0-mlogloss:0.97598
# [132]	validation_0-mlogloss:0.97603
# [133]	validation_0-mlogloss:0.97609
# [134]	validation_0-mlogloss:0.97604
# [135]	validation_0-mlogloss:0.97607
# [136]	validation_0-mlogloss:0.97612
# [137]	validation_0-mlogloss:0.97614
# [138]	validation_0-mlogloss:0.97609
# [139]	validation_0-mlogloss:0.97620
# [140]	validation_0-mlogloss:0.97627
# [141]	validation_0-mlogloss:0.97625
# [142]	validation_0-mlogloss:0.97625
# [143]	validation_0-mlogloss:0.97626
# [144]	validation_0-mlogloss:0.97624
# [145]	validation_0-mlogloss:0.97623
# [146]	validation_0-mlogloss:0.97623
# [147]	validation_0-mlogloss:0.97618
# [148]	validation_0-mlogloss:0.97628
# [149]	validation_0-mlogloss:0.97627
# [150]	validation_0-mlogloss:0.97628
# [151]	validation_0-mlogloss:0.97631
# [152]	validation_0-mlogloss:0.97631
# [153]	validation_0-mlogloss:0.97636
# [154]	validation_0-mlogloss:0.97637
# [155]	validation_0-mlogloss:0.97628
# [156]	validation_0-mlogloss:0.97634
# [157]	validation_0-mlogloss:0.97637
# [158]	validation_0-mlogloss:0.97641
# [159]	validation_0-mlogloss:0.97650
# [160]	validation_0-mlogloss:0.97661
# [161]	validation_0-mlogloss:0.97661
# [162]	validation_0-mlogloss:0.97654
# [163]	validation_0-mlogloss:0.97654
# [164]	validation_0-mlogloss:0.97660
# [165]	validation_0-mlogloss:0.97669
# [166]	validation_0-mlogloss:0.97675
# [167]	validation_0-mlogloss:0.97683
# [168]	validation_0-mlogloss:0.97685
# [169]	validation_0-mlogloss:0.97691
# [170]	validation_0-mlogloss:0.97687
# [171]	validation_0-mlogloss:0.97686
# [172]	validation_0-mlogloss:0.97693
# [173]	validation_0-mlogloss:0.97696
# [174]	validation_0-mlogloss:0.97700
# [175]	validation_0-mlogloss:0.97698
# [176]	validation_0-mlogloss:0.97694
# [177]	validation_0-mlogloss:0.97693
# [178]	validation_0-mlogloss:0.97709
# [179]	validation_0-mlogloss:0.97713
# [180]	validation_0-mlogloss:0.97712
# [181]	validation_0-mlogloss:0.97718
# [182]	validation_0-mlogloss:0.97715
# [183]	validation_0-mlogloss:0.97715
# [184]	validation_0-mlogloss:0.97721
# [185]	validation_0-mlogloss:0.97723
# [186]	validation_0-mlogloss:0.97724
# [187]	validation_0-mlogloss:0.97726
# [188]	validation_0-mlogloss:0.97727
# [189]	validation_0-mlogloss:0.97730
# [190]	validation_0-mlogloss:0.97729
# [191]	validation_0-mlogloss:0.97733
# [192]	validation_0-mlogloss:0.97733
# [193]	validation_0-mlogloss:0.97732
# [194]	validation_0-mlogloss:0.97737
# [195]	validation_0-mlogloss:0.97745
# [196]	validation_0-mlogloss:0.97739
# [197]	validation_0-mlogloss:0.97728
# [198]	validation_0-mlogloss:0.97727
# [199]	validation_0-mlogloss:0.97729
# [200]	validation_0-mlogloss:0.97730
# [201]	validation_0-mlogloss:0.97736
# [202]	validation_0-mlogloss:0.97737
# [203]	validation_0-mlogloss:0.97743
# [204]	validation_0-mlogloss:0.97737
# [205]	validation_0-mlogloss:0.97738
# [206]	validation_0-mlogloss:0.97737
# [207]	validation_0-mlogloss:0.97739
# [208]	validation_0-mlogloss:0.97752
# [209]	validation_0-mlogloss:0.97753
# [210]	validation_0-mlogloss:0.97753
# [211]	validation_0-mlogloss:0.97761
# [212]	validation_0-mlogloss:0.97758
# [213]	validation_0-mlogloss:0.97752
# [214]	validation_0-mlogloss:0.97748
# [215]	validation_0-mlogloss:0.97751
# [216]	validation_0-mlogloss:0.97748
# [217]	validation_0-mlogloss:0.97744
# [218]	validation_0-mlogloss:0.97744
# [219]	validation_0-mlogloss:0.97747
# [220]	validation_0-mlogloss:0.97745
# [221]	validation_0-mlogloss:0.97740
# [222]	validation_0-mlogloss:0.97741
# [223]	validation_0-mlogloss:0.97742
# [224]	validation_0-mlogloss:0.97738
# [225]	validation_0-mlogloss:0.97743
# [226]	validation_0-mlogloss:0.97742
# [227]	validation_0-mlogloss:0.97742
# [228]	validation_0-mlogloss:0.97751
# [229]	validation_0-mlogloss:0.97753
# [230]	validation_0-mlogloss:0.97751
# [231]	validation_0-mlogloss:0.97752
# [232]	validation_0-mlogloss:0.97751
# [233]	validation_0-mlogloss:0.97751
# [234]	validation_0-mlogloss:0.97751
# [235]	validation_0-mlogloss:0.97751
# [236]	validation_0-mlogloss:0.97751
# [237]	validation_0-mlogloss:0.97751
# [238]	validation_0-mlogloss:0.97751
# [239]	validation_0-mlogloss:0.97751
# [240]	validation_0-mlogloss:0.97751
# [241]	validation_0-mlogloss:0.97751
# [242]	validation_0-mlogloss:0.97751
# [243]	validation_0-mlogloss:0.97751
# [244]	validation_0-mlogloss:0.97751
# [245]	validation_0-mlogloss:0.97750
# [246]	validation_0-mlogloss:0.97750
# [247]	validation_0-mlogloss:0.97750
# [248]	validation_0-mlogloss:0.97750
# [249]	validation_0-mlogloss:0.97750
# [250]	validation_0-mlogloss:0.97750
# [251]	validation_0-mlogloss:0.97750
# [252]	validation_0-mlogloss:0.97750
# [253]	validation_0-mlogloss:0.97750
# [254]	validation_0-mlogloss:0.97750
# [255]	validation_0-mlogloss:0.97750
# [256]	validation_0-mlogloss:0.97750
# [257]	validation_0-mlogloss:0.97750
# [258]	validation_0-mlogloss:0.97750
# [259]	validation_0-mlogloss:0.97750
# [260]	validation_0-mlogloss:0.97750
# [261]	validation_0-mlogloss:0.97750
# [262]	validation_0-mlogloss:0.97750
# [263]	validation_0-mlogloss:0.97750
# [264]	validation_0-mlogloss:0.97750
# [265]	validation_0-mlogloss:0.97750
# [266]	validation_0-mlogloss:0.97750
# [267]	validation_0-mlogloss:0.97750
# [268]	validation_0-mlogloss:0.97750
# [269]	validation_0-mlogloss:0.97750
# [270]	validation_0-mlogloss:0.97750
# [271]	validation_0-mlogloss:0.97750
# [272]	validation_0-mlogloss:0.97750
# [273]	validation_0-mlogloss:0.97750
# [274]	validation_0-mlogloss:0.97750
# [275]	validation_0-mlogloss:0.97750
# [276]	validation_0-mlogloss:0.97750
# [277]	validation_0-mlogloss:0.97750
# [278]	validation_0-mlogloss:0.97750
# [279]	validation_0-mlogloss:0.97750
# [280]	validation_0-mlogloss:0.97750
# [281]	validation_0-mlogloss:0.97750
# [282]	validation_0-mlogloss:0.97750
# [283]	validation_0-mlogloss:0.97750
# [284]	validation_0-mlogloss:0.97750
# [285]	validation_0-mlogloss:0.97750
# [286]	validation_0-mlogloss:0.97750
# [287]	validation_0-mlogloss:0.97750
# [288]	validation_0-mlogloss:0.97750
# [289]	validation_0-mlogloss:0.97750
# [290]	validation_0-mlogloss:0.97750
# [291]	validation_0-mlogloss:0.97750
# [292]	validation_0-mlogloss:0.97750
# [293]	validation_0-mlogloss:0.97750
# [294]	validation_0-mlogloss:0.97750
# [295]	validation_0-mlogloss:0.97750
# [296]	validation_0-mlogloss:0.97750
# [297]	validation_0-mlogloss:0.97750
# [298]	validation_0-mlogloss:0.97750
# [299]	validation_0-mlogloss:0.97750
# Confusion Matrix:
#  [[1052 1034 1234]
#  [2464 3633 4298]
#  [2689 3199 9331]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          <30       0.17      0.32      0.22      3320
#          >30       0.46      0.35      0.40     10395
#           NO       0.63      0.61      0.62     15219
#
#     accuracy                           0.48     28934
#    macro avg       0.42      0.43      0.41     28934
# weighted avg       0.52      0.48      0.49     28934

# %%
# Save the final trained model
final_model.save_model("xgb_model.json")

# %%
# Save model as JSON (recommended for MCP/XGBoost tools)
xgb.save_model("xgb_model.json")

# %%
y_pred = xgb.predict(X_test)
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# %%
samples = []
for class_label in [0, 1, 2]:
    subset = X_test[y_test == class_label]
    samples.append(subset.sample(n=20, random_state=42))

sample_df = pd.concat(samples)
sample_preds = xgb.predict(sample_df)

print("\nSample Predictions (20 per class):")
print(pd.DataFrame({
    'Actual': y.loc[sample_df.index],
    'Predicted': sample_preds
}))

# %%
# Combine the samples into one test DataFrame
sample_df = pd.concat(samples)

# Save the test input without 'readmitted' label to CSV
sample_df.to_csv("test_set_for_claude.csv", index=False)
